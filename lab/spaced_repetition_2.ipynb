# %%
import pandas as pd
from datetime import datetime
import pytz

# %%
import anvil.server

anvil.server.connect("client_KYOM4YFDIE4TMEO3UAOTEPRC-55C7JZ62MGB2UXA6")

# %%
from anvil.tables import app_tables

answers = app_tables.answers.search()

# %%
answers_list = [
    {
        "created_at": r["created_at"],
        "question_data": r["question"],
        "question_txt": r["question"]["question"],
        "question_title": r["question"]["title"],
        "question_type": r["question"]["type"],
        "question_level": r["question"]["level"],
        "got_it_right": r["got_it_right"],
        "session": r["session"],
        "user": r["user"]["email"] if r["user"] else "",
    }
    for r in answers
]

answers_list
# Out:
# [{'created_at': datetime.datetime(2024, 8, 15, 16, 44, 24, 571000, tzinfo=<anvil.tz.tzoffset (-3.0 hour offset)>),
#   'question_data': <LiveObject: anvil.tables.Row>,
#   'question_txt': 'Entropy is a measure of the average uncertainty in a set of outcomes, while cross-entropy measures the difference between two probability distributions.',
#   'question_title': 'Probability - LLMs',
#   'question_type': 'true_or_false',
#   'question_level': 'easy',
#   'got_it_right': False,
#   'session': '10071df2-2c28-4c47-896d-61ac89d3883a',
#   'user': 'teste@teste.com'},
#  {'created_at': datetime.datetime(2024, 8, 15, 16, 44, 29, 268000, tzinfo=<anvil.tz.tzoffset (-3.0 hour offset)>),
#   'question_data': <LiveObject: anvil.tables.Row>,
#   'question_txt': 'Cross-entropy loss measures the difference between predicted probabilities and actual outcomes, while entropy quantifies the uncertainty in a probability distribution.',
#   'question_title': 'Probability - LLMs',
#   'question_type': 'true_or_false',
#   'question_level': 'easy',
#   'got_it_right': True,
#   'session': '10071df2-2c28-4c47-896d-61ac89d3883a',
#   'user': 'teste@teste.com'},
#  {'created_at': datetime.datetime(2024, 8, 15, 16, 44, 31, 959000, tzinfo=<anvil.tz.tzoffset (-3.0 hour offset)>),
#   'question_data': <LiveObject: anvil.tables.Row>,
#   'question_txt': 'Entropy is a measure of uncertainty in a probability distribution, while cross-entropy measures the difference between two probability distributions.',
#   'question_title': 'Probability - LLMs',
#   'question_type': 'true_or_false',
#   'question_level': 'easy',
#   'got_it_right': True,
#   'session': '10071df2-2c28-4c47-896d-61ac89d3883a',
#   'user': 'teste@teste.com'},
#  {'created_at': datetime.datetime(2024, 8, 15, 16, 44, 35, 482000, tzinfo=<anvil.tz.tzoffset (-3.0 hour offset)>),
#   'question_data': <LiveObject: anvil.tables.Row>,
#   'question_txt': 'Cross-entropy loss is the same as perplexity, used to evaluate language models.',
#   'question_title': 'Probability - LLMs',
#   'question_type': 'true_or_false',
#   'question_level': 'easy',
#   'got_it_right': True,
#   'session': '10071df2-2c28-4c47-896d-61ac89d3883a',
#   'user': 'teste@teste.com'},
#  {'created_at': datetime.datetime(2024, 8, 15, 16, 45, 10, 548000, tzinfo=<anvil.tz.tzoffset (-3.0 hour offset)>),
#   'question_data': <LiveObject: anvil.tables.Row>,
#   'question_txt': 'Entropy is a measure of the average uncertainty in a set of outcomes, while cross-entropy measures the difference between two probability distributions.',
#   'question_title': 'Probability - LLMs',
#   'question_type': 'true_or_false',
#   'question_level': 'easy',
#   'got_it_right': False,
#   'session': 'a25f3257-1470-41d8-07a6-3a23cf8c1512',
#   'user': 'teste@teste.com'},
#  {'created_at': datetime.datetime(2024, 8, 15, 16, 45, 13, 482000, tzinfo=<anvil.tz.tzoffset (-3.0 hour offset)>),
#   'question_data': <LiveObject: anvil.tables.Row>,
#   'question_txt': 'Cross-entropy loss measures the difference between predicted probabilities and actual outcomes, while entropy quantifies the uncertainty in a probability distribution.',
#   'question_title': 'Probability - LLMs',
#   'question_type': 'true_or_false',
#   'question_level': 'easy',
#   'got_it_right': True,
#   'session': 'a25f3257-1470-41d8-07a6-3a23cf8c1512',
#   'user': 'teste@teste.com'},
#  {'created_at': datetime.datetime(2024, 8, 15, 17, 0, 4, 336000, tzinfo=<anvil.tz.tzoffset (-3.0 hour offset)>),
#   'question_data': <LiveObject: anvil.tables.Row>,
#   'question_txt': 'A linear transformation preserves linear combinations of vectors, but not their magnitudes.',
#   'question_title': 'Linear Algebra - Basics',
#   'question_type': 'true_or_false',
#   'question_level': 'medium',
#   'got_it_right': True,
#   'session': 'a04dda00-ef64-8199-bf50-dd68689cccba',
#   'user': 'teste@teste.com'},
#  {'created_at': datetime.datetime(2024, 8, 15, 17, 0, 28, 857000, tzinfo=<anvil.tz.tzoffset (-3.0 hour offset)>),
#   'question_data': <LiveObject: anvil.tables.Row>,
#   'question_txt': 'Cross-Entropy is always less than or equal to Entropy for a given probability distribution.',
#   'question_title': 'Probability - LLMs',
#   'question_type': 'true_or_false',
#   'question_level': 'medium',
#   'got_it_right': False,
#   'session': 'a04dda00-ef64-8199-bf50-dd68689cccba',
#   'user': 'teste@teste.com'},
#  {'created_at': datetime.datetime(2024, 8, 21, 16, 23, 20, 760000, tzinfo=<anvil.tz.tzoffset (-3.0 hour offset)>),
#   'question_data': <LiveObject: anvil.tables.Row>,
#   'question_txt': "Perplexity is used as a loss function in machine learning models to optimize the model's performance.",
#   'question_title': 'Probability - LLMs',
#   'question_type': 'true_or_false',
#   'question_level': 'medium',
#   'got_it_right': True,
#   'session': '94653bb8-c306-1ec1-0506-82af1a6fb586',
#   'user': 'teste@teste.com'},
#  {'created_at': datetime.datetime(2024, 8, 21, 16, 42, 17, 874000, tzinfo=<anvil.tz.tzoffset (-3.0 hour offset)>),
#   'question_data': <LiveObject: anvil.tables.Row>,
#   'question_txt': 'Minimizing cross-entropy loss during training improves the performance of a language model.',
#   'question_title': 'Probability - LLMs',
#   'question_type': 'true_or_false',
#   'question_level': 'easy',
#   'got_it_right': True,
#   'session': '5e189bba-fdf0-b5cb-fb32-3658f4918466',
#   'user': 'teste@teste.com'},
#  {'created_at': datetime.datetime(2024, 8, 21, 20, 19, 44, 239000, tzinfo=<anvil.tz.tzoffset (-3.0 hour offset)>),
#   'question_data': <LiveObject: anvil.tables.Row>,
#   'question_txt': 'Recall measures the ability of a model to identify all relevant instances in a dataset.',
#   'question_title': 'Model performance',
#   'question_type': 'true_or_false',
#   'question_level': 'easy',
#   'got_it_right': True,
#   'session': '3569b7df-fa07-35db-9c8c-088a6958310e',
#   'user': 'rhuanbarros@gmail.com'},
#  {'created_at': datetime.datetime(2024, 8, 21, 20, 20, 11, 950000, tzinfo=<anvil.tz.tzoffset (-3.0 hour offset)>),
#   'question_data': <LiveObject: anvil.tables.Row>,
#   'question_txt': 'Precision is the ratio of true positives to the sum of true positives and true negatives.',
#   'question_title': 'Model performance',
#   'question_type': 'true_or_false',
#   'question_level': 'easy',
#   'got_it_right': False,
#   'session': '3569b7df-fa07-35db-9c8c-088a6958310e',
#   'user': 'rhuanbarros@gmail.com'},
#  {'created_at': datetime.datetime(2024, 8, 23, 12, 28, 23, 797000, tzinfo=<anvil.tz.tzoffset (-3.0 hour offset)>),
#   'question_data': <LiveObject: anvil.tables.Row>,
#   'question_txt': 'Neural networks are inspired by the functioning of the human brain.',
#   'question_title': 'Machine Learning basics',
#   'question_type': 'true_or_false',
#   'question_level': 'beginner',
#   'got_it_right': True,
#   'session': 'e03e98b3-381b-51ea-1020-1a0da855e420',
#   'user': 'rhuanbarros@gmail.com'},
#  {'created_at': datetime.datetime(2024, 8, 23, 12, 28, 29, 743000, tzinfo=<anvil.tz.tzoffset (-3.0 hour offset)>),
#   'question_data': <LiveObject: anvil.tables.Row>,
#   'question_txt': 'Accuracy is the best metric for imbalanced datasets.',
#   'question_title': 'Machine Learning basics',
#   'question_type': 'true_or_false',
#   'question_level': 'beginner',
#   'got_it_right': True,
#   'session': 'e03e98b3-381b-51ea-1020-1a0da855e420',
#   'user': 'rhuanbarros@gmail.com'},
#  {'created_at': datetime.datetime(2024, 8, 23, 12, 28, 48, 364000, tzinfo=<anvil.tz.tzoffset (-3.0 hour offset)>),
#   'question_data': <LiveObject: anvil.tables.Row>,
#   'question_txt': 'Increasing model complexity typically reduces bias and increases variance.',
#   'question_title': 'Machine Learning basics',
#   'question_type': 'true_or_false',
#   'question_level': 'beginner',
#   'got_it_right': True,
#   'session': 'e03e98b3-381b-51ea-1020-1a0da855e420',
#   'user': 'rhuanbarros@gmail.com'},
#  {'created_at': datetime.datetime(2024, 8, 23, 12, 28, 58, 448000, tzinfo=<anvil.tz.tzoffset (-3.0 hour offset)>),
#   'question_data': <LiveObject: anvil.tables.Row>,
#   'question_txt': 'Logistic Regression is used for regression tasks, not classification.',
#   'question_title': 'Machine Learning basics',
#   'question_type': 'true_or_false',
#   'question_level': 'beginner',
#   'got_it_right': True,
#   'session': 'e03e98b3-381b-51ea-1020-1a0da855e420',
#   'user': 'rhuanbarros@gmail.com'},
#  {'created_at': datetime.datetime(2024, 8, 23, 12, 29, 8, 550000, tzinfo=<anvil.tz.tzoffset (-3.0 hour offset)>),
#   'question_data': <LiveObject: anvil.tables.Row>,
#   'question_txt': 'Cross-validation is a technique used to train a model on multiple subsets of the data and then average the results.',
#   'question_title': 'Machine Learning basics',
#   'question_type': 'true_or_false',
#   'question_level': 'beginner',
#   'got_it_right': True,
#   'session': 'e03e98b3-381b-51ea-1020-1a0da855e420',
#   'user': 'rhuanbarros@gmail.com'},
#  {'created_at': datetime.datetime(2024, 8, 23, 12, 29, 43, 915000, tzinfo=<anvil.tz.tzoffset (-3.0 hour offset)>),
#   'question_data': <LiveObject: anvil.tables.Row>,
#   'question_txt': 'Classification is a type of unsupervised learning technique.',
#   'question_title': 'Machine Learning basics',
#   'question_type': 'true_or_false',
#   'question_level': 'beginner',
#   'got_it_right': True,
#   'session': 'e03e98b3-381b-51ea-1020-1a0da855e420',
#   'user': 'rhuanbarros@gmail.com'},
#  {'created_at': datetime.datetime(2024, 8, 23, 12, 29, 55, 815000, tzinfo=<anvil.tz.tzoffset (-3.0 hour offset)>),
#   'question_data': <LiveObject: anvil.tables.Row>,
#   'question_txt': 'PCA is a supervised learning technique.',
#   'question_title': 'Machine Learning basics',
#   'question_type': 'true_or_false',
#   'question_level': 'beginner',
#   'got_it_right': True,
#   'session': 'e03e98b3-381b-51ea-1020-1a0da855e420',
#   'user': 'rhuanbarros@gmail.com'},
#  {'created_at': datetime.datetime(2024, 8, 23, 12, 30, 1, 366000, tzinfo=<anvil.tz.tzoffset (-3.0 hour offset)>),
#   'question_data': <LiveObject: anvil.tables.Row>,
#   'question_txt': 'Logistic regression is used for continuous target variables.',
#   'question_title': 'Machine Learning basics',
#   'question_type': 'true_or_false',
#   'question_level': 'beginner',
#   'got_it_right': True,
#   'session': 'e03e98b3-381b-51ea-1020-1a0da855e420',
#   'user': 'rhuanbarros@gmail.com'},
#  {'created_at': datetime.datetime(2024, 8, 23, 12, 30, 7, 4000, tzinfo=<anvil.tz.tzoffset (-3.0 hour offset)>),
#   'question_data': <LiveObject: anvil.tables.Row>,
#   'question_txt': 'Feature scaling is not necessary in machine learning.',
#   'question_title': 'Machine Learning basics',
#   'question_type': 'true_or_false',
#   'question_level': 'beginner',
#   'got_it_right': True,
#   'session': 'e03e98b3-381b-51ea-1020-1a0da855e420',
#   'user': 'rhuanbarros@gmail.com'},
#  {'created_at': datetime.datetime(2024, 8, 23, 12, 30, 25, 179000, tzinfo=<anvil.tz.tzoffset (-3.0 hour offset)>),
#   'question_data': <LiveObject: anvil.tables.Row>,
#   'question_txt': 'Cross-validation is a technique used to prevent underfitting in machine learning models.',
#   'question_title': 'Machine Learning basics',
#   'question_type': 'true_or_false',
#   'question_level': 'beginner',
#   'got_it_right': True,
#   'session': 'e03e98b3-381b-51ea-1020-1a0da855e420',
#   'user': 'rhuanbarros@gmail.com'},
#  {'created_at': datetime.datetime(2024, 8, 23, 12, 30, 36, 985000, tzinfo=<anvil.tz.tzoffset (-3.0 hour offset)>),
#   'question_data': <LiveObject: anvil.tables.Row>,
#   'question_txt': 'Feature scaling is not necessary for tree-based models.',
#   'question_title': 'Machine Learning basics',
#   'question_type': 'true_or_false',
#   'question_level': 'beginner',
#   'got_it_right': True,
#   'session': 'e03e98b3-381b-51ea-1020-1a0da855e420',
#   'user': 'rhuanbarros@gmail.com'},
#  {'created_at': datetime.datetime(2024, 8, 23, 12, 30, 50, 406000, tzinfo=<anvil.tz.tzoffset (-3.0 hour offset)>),
#   'question_data': <LiveObject: anvil.tables.Row>,
#   'question_txt': 'Increasing model complexity often leads to lower bias and higher variance.',
#   'question_title': 'Machine Learning basics',
#   'question_type': 'true_or_false',
#   'question_level': 'beginner',
#   'got_it_right': True,
#   'session': 'e03e98b3-381b-51ea-1020-1a0da855e420',
#   'user': 'rhuanbarros@gmail.com'},
#  {'created_at': datetime.datetime(2024, 8, 23, 12, 31, 0, 646000, tzinfo=<anvil.tz.tzoffset (-3.0 hour offset)>),
#   'question_data': <LiveObject: anvil.tables.Row>,
#   'question_txt': 'Feature engineering is the process of selecting the most complex features for a model.',
#   'question_title': 'Machine Learning basics',
#   'question_type': 'true_or_false',
#   'question_level': 'beginner',
#   'got_it_right': True,
#   'session': 'e03e98b3-381b-51ea-1020-1a0da855e420',
#   'user': 'rhuanbarros@gmail.com'},
#  {'created_at': datetime.datetime(2024, 8, 23, 17, 11, 14, 828000, tzinfo=<anvil.tz.tzoffset (-3.0 hour offset)>),
#   'question_data': <LiveObject: anvil.tables.Row>,
#   'question_txt': 'Increasing model complexity typically reduces bias and increases variance.',
#   'question_title': 'Machine Learning basics',
#   'question_type': 'true_or_false',
#   'question_level': 'beginner',
#   'got_it_right': True,
#   'session': '1d39bb99-5b10-cfba-8abf-1c12cf1e63a9',
#   'user': 'rhuanbarros@gmail.com'},
#  {'created_at': datetime.datetime(2024, 8, 23, 17, 11, 21, 362000, tzinfo=<anvil.tz.tzoffset (-3.0 hour offset)>),
#   'question_data': <LiveObject: anvil.tables.Row>,
#   'question_txt': 'Precision and recall are two common evaluation metrics for classification models.',
#   'question_title': 'Machine Learning basics',
#   'question_type': 'true_or_false',
#   'question_level': 'beginner',
#   'got_it_right': True,
#   'session': '1d39bb99-5b10-cfba-8abf-1c12cf1e63a9',
#   'user': 'rhuanbarros@gmail.com'},
#  {'created_at': datetime.datetime(2024, 8, 23, 17, 11, 29, 831000, tzinfo=<anvil.tz.tzoffset (-3.0 hour offset)>),
#   'question_data': <LiveObject: anvil.tables.Row>,
#   'question_txt': 'Increasing model complexity often leads to lower bias and higher variance.',
#   'question_title': 'Machine Learning basics',
#   'question_type': 'true_or_false',
#   'question_level': 'beginner',
#   'got_it_right': True,
#   'session': '1d39bb99-5b10-cfba-8abf-1c12cf1e63a9',
#   'user': 'rhuanbarros@gmail.com'},
#  {'created_at': datetime.datetime(2024, 8, 23, 17, 11, 35, 401000, tzinfo=<anvil.tz.tzoffset (-3.0 hour offset)>),
#   'question_data': <LiveObject: anvil.tables.Row>,
#   'question_txt': 'Classification is a type of unsupervised learning technique.',
#   'question_title': 'Machine Learning basics',
#   'question_type': 'true_or_false',
#   'question_level': 'beginner',
#   'got_it_right': True,
#   'session': '1d39bb99-5b10-cfba-8abf-1c12cf1e63a9',
#   'user': 'rhuanbarros@gmail.com'},
#  {'created_at': datetime.datetime(2024, 8, 23, 17, 11, 39, 571000, tzinfo=<anvil.tz.tzoffset (-3.0 hour offset)>),
#   'question_data': <LiveObject: anvil.tables.Row>,
#   'question_txt': 'Logistic regression is used for continuous target variables.',
#   'question_title': 'Machine Learning basics',
#   'question_type': 'true_or_false',
#   'question_level': 'beginner',
#   'got_it_right': True,
#   'session': '1d39bb99-5b10-cfba-8abf-1c12cf1e63a9',
#   'user': 'rhuanbarros@gmail.com'},
#  {'created_at': datetime.datetime(2024, 8, 23, 17, 11, 45, 280000, tzinfo=<anvil.tz.tzoffset (-3.0 hour offset)>),
#   'question_data': <LiveObject: anvil.tables.Row>,
#   'question_txt': 'Having high bias in a model can lead to overfitting.',
#   'question_title': 'Machine Learning basics',
#   'question_type': 'true_or_false',
#   'question_level': 'beginner',
#   'got_it_right': True,
#   'session': '1d39bb99-5b10-cfba-8abf-1c12cf1e63a9',
#   'user': 'rhuanbarros@gmail.com'},
#  {'created_at': datetime.datetime(2024, 8, 23, 17, 11, 57, 279000, tzinfo=<anvil.tz.tzoffset (-3.0 hour offset)>),
#   'question_data': <LiveObject: anvil.tables.Row>,
#   'question_txt': 'Regularization is a technique used to encourage complex models in machine learning.',
#   'question_title': 'Machine Learning basics',
#   'question_type': 'true_or_false',
#   'question_level': 'beginner',
#   'got_it_right': False,
#   'session': '1d39bb99-5b10-cfba-8abf-1c12cf1e63a9',
#   'user': 'rhuanbarros@gmail.com'},
#  {'created_at': datetime.datetime(2024, 8, 23, 17, 12, 11, 243000, tzinfo=<anvil.tz.tzoffset (-3.0 hour offset)>),
#   'question_data': <LiveObject: anvil.tables.Row>,
#   'question_txt': 'Cross-validation is a technique used to prevent underfitting in machine learning models.',
#   'question_title': 'Machine Learning basics',
#   'question_type': 'true_or_false',
#   'question_level': 'beginner',
#   'got_it_right': True,
#   'session': '1d39bb99-5b10-cfba-8abf-1c12cf1e63a9',
#   'user': 'rhuanbarros@gmail.com'},
#  {'created_at': datetime.datetime(2024, 8, 23, 17, 12, 16, 734000, tzinfo=<anvil.tz.tzoffset (-3.0 hour offset)>),
#   'question_data': <LiveObject: anvil.tables.Row>,
#   'question_txt': 'PCA is a supervised learning technique.',
#   'question_title': 'Machine Learning basics',
#   'question_type': 'true_or_false',
#   'question_level': 'beginner',
#   'got_it_right': False,
#   'session': '1d39bb99-5b10-cfba-8abf-1c12cf1e63a9',
#   'user': 'rhuanbarros@gmail.com'},
#  {'created_at': datetime.datetime(2024, 8, 23, 17, 12, 23, 610000, tzinfo=<anvil.tz.tzoffset (-3.0 hour offset)>),
#   'question_data': <LiveObject: anvil.tables.Row>,
#   'question_txt': 'Overfitting occurs when a model performs well on the training data but poorly on new, unseen data.',
#   'question_title': 'Machine Learning basics',
#   'question_type': 'true_or_false',
#   'question_level': 'beginner',
#   'got_it_right': True,
#   'session': '1d39bb99-5b10-cfba-8abf-1c12cf1e63a9',
#   'user': 'rhuanbarros@gmail.com'},
#  {'created_at': datetime.datetime(2024, 8, 23, 17, 12, 30, 110000, tzinfo=<anvil.tz.tzoffset (-3.0 hour offset)>),
#   'question_data': <LiveObject: anvil.tables.Row>,
#   'question_txt': 'Feature scaling is not necessary for tree-based models.',
#   'question_title': 'Machine Learning basics',
#   'question_type': 'true_or_false',
#   'question_level': 'beginner',
#   'got_it_right': True,
#   'session': '1d39bb99-5b10-cfba-8abf-1c12cf1e63a9',
#   'user': 'rhuanbarros@gmail.com'},
#  {'created_at': datetime.datetime(2024, 8, 23, 17, 12, 34, 536000, tzinfo=<anvil.tz.tzoffset (-3.0 hour offset)>),
#   'question_data': <LiveObject: anvil.tables.Row>,
#   'question_txt': 'Logistic Regression is used for regression tasks, not classification.',
#   'question_title': 'Machine Learning basics',
#   'question_type': 'true_or_false',
#   'question_level': 'beginner',
#   'got_it_right': True,
#   'session': '1d39bb99-5b10-cfba-8abf-1c12cf1e63a9',
#   'user': 'rhuanbarros@gmail.com'},
#  {'created_at': datetime.datetime(2024, 8, 23, 17, 12, 40, 435000, tzinfo=<anvil.tz.tzoffset (-3.0 hour offset)>),
#   'question_data': <LiveObject: anvil.tables.Row>,
#   'question_txt': 'Random Forest is an example of a single learning algorithm, not an ensemble method.',
#   'question_title': 'Machine Learning basics',
#   'question_type': 'true_or_false',
#   'question_level': 'beginner',
#   'got_it_right': True,
#   'session': '1d39bb99-5b10-cfba-8abf-1c12cf1e63a9',
#   'user': 'rhuanbarros@gmail.com'},
#  {'created_at': datetime.datetime(2024, 8, 23, 17, 12, 45, 232000, tzinfo=<anvil.tz.tzoffset (-3.0 hour offset)>),
#   'question_data': <LiveObject: anvil.tables.Row>,
#   'question_txt': 'Feature engineering is the process of selecting the most complex features for a model.',
#   'question_title': 'Machine Learning basics',
#   'question_type': 'true_or_false',
#   'question_level': 'beginner',
#   'got_it_right': True,
#   'session': '1d39bb99-5b10-cfba-8abf-1c12cf1e63a9',
#   'user': 'rhuanbarros@gmail.com'},
#  {'created_at': datetime.datetime(2024, 8, 23, 17, 12, 49, 796000, tzinfo=<anvil.tz.tzoffset (-3.0 hour offset)>),
#   'question_data': <LiveObject: anvil.tables.Row>,
#   'question_txt': 'Overfitting occurs when a model performs well on the training data but poorly on unseen data.',
#   'question_title': 'Machine Learning basics',
#   'question_type': 'true_or_false',
#   'question_level': 'beginner',
#   'got_it_right': True,
#   'session': '1d39bb99-5b10-cfba-8abf-1c12cf1e63a9',
#   'user': 'rhuanbarros@gmail.com'},
#  {'created_at': datetime.datetime(2024, 8, 23, 17, 12, 56, 217000, tzinfo=<anvil.tz.tzoffset (-3.0 hour offset)>),
#   'question_data': <LiveObject: anvil.tables.Row>,
#   'question_txt': 'Decision trees are used only for regression tasks and not for classification.',
#   'question_title': 'Machine Learning basics',
#   'question_type': 'true_or_false',
#   'question_level': 'beginner',
#   'got_it_right': True,
#   'session': '1d39bb99-5b10-cfba-8abf-1c12cf1e63a9',
#   'user': 'rhuanbarros@gmail.com'},
#  {'created_at': datetime.datetime(2024, 8, 23, 17, 12, 59, 867000, tzinfo=<anvil.tz.tzoffset (-3.0 hour offset)>),
#   'question_data': <LiveObject: anvil.tables.Row>,
#   'question_txt': 'Decision trees are used only for regression problems.',
#   'question_title': 'Machine Learning basics',
#   'question_type': 'true_or_false',
#   'question_level': 'beginner',
#   'got_it_right': True,
#   'session': '1d39bb99-5b10-cfba-8abf-1c12cf1e63a9',
#   'user': 'rhuanbarros@gmail.com'},
#  {'created_at': datetime.datetime(2024, 8, 23, 17, 13, 4, 348000, tzinfo=<anvil.tz.tzoffset (-3.0 hour offset)>),
#   'question_data': <LiveObject: anvil.tables.Row>,
#   'question_txt': 'Accuracy is the best metric for imbalanced datasets.',
#   'question_title': 'Machine Learning basics',
#   'question_type': 'true_or_false',
#   'question_level': 'beginner',
#   'got_it_right': True,
#   'session': '1d39bb99-5b10-cfba-8abf-1c12cf1e63a9',
#   'user': 'rhuanbarros@gmail.com'},
#  {'created_at': datetime.datetime(2024, 8, 23, 17, 13, 9, 119000, tzinfo=<anvil.tz.tzoffset (-3.0 hour offset)>),
#   'question_data': <LiveObject: anvil.tables.Row>,
#   'question_txt': 'Feature scaling is not necessary in machine learning.',
#   'question_title': 'Machine Learning basics',
#   'question_type': 'true_or_false',
#   'question_level': 'beginner',
#   'got_it_right': True,
#   'session': '1d39bb99-5b10-cfba-8abf-1c12cf1e63a9',
#   'user': 'rhuanbarros@gmail.com'},
#  {'created_at': datetime.datetime(2024, 8, 23, 17, 13, 19, 10000, tzinfo=<anvil.tz.tzoffset (-3.0 hour offset)>),
#   'question_data': <LiveObject: anvil.tables.Row>,
#   'question_txt': 'Neural networks with more hidden layers are always better than shallow networks.',
#   'question_title': 'Machine Learning basics',
#   'question_type': 'true_or_false',
#   'question_level': 'beginner',
#   'got_it_right': True,
#   'session': '1d39bb99-5b10-cfba-8abf-1c12cf1e63a9',
#   'user': 'rhuanbarros@gmail.com'},
#  {'created_at': datetime.datetime(2024, 8, 23, 17, 13, 25, 131000, tzinfo=<anvil.tz.tzoffset (-3.0 hour offset)>),
#   'question_data': <LiveObject: anvil.tables.Row>,
#   'question_txt': 'K-Nearest Neighbors (KNN) is a supervised learning algorithm.',
#   'question_title': 'Machine Learning basics',
#   'question_type': 'true_or_false',
#   'question_level': 'beginner',
#   'got_it_right': True,
#   'session': '1d39bb99-5b10-cfba-8abf-1c12cf1e63a9',
#   'user': 'rhuanbarros@gmail.com'},
#  {'created_at': datetime.datetime(2024, 8, 23, 17, 13, 35, 797000, tzinfo=<anvil.tz.tzoffset (-3.0 hour offset)>),
#   'question_data': <LiveObject: anvil.tables.Row>,
#   'question_txt': 'Cross-validation is a technique used to train a model on multiple subsets of the data and then average the results.',
#   'question_title': 'Machine Learning basics',
#   'question_type': 'true_or_false',
#   'question_level': 'beginner',
#   'got_it_right': True,
#   'session': '1d39bb99-5b10-cfba-8abf-1c12cf1e63a9',
#   'user': 'rhuanbarros@gmail.com'},
#  {'created_at': datetime.datetime(2024, 8, 23, 17, 13, 45, 520000, tzinfo=<anvil.tz.tzoffset (-3.0 hour offset)>),
#   'question_data': <LiveObject: anvil.tables.Row>,
#   'question_txt': 'Bagging and Boosting are types of unsupervised learning techniques.',
#   'question_title': 'Machine Learning basics',
#   'question_type': 'true_or_false',
#   'question_level': 'beginner',
#   'got_it_right': True,
#   'session': '1d39bb99-5b10-cfba-8abf-1c12cf1e63a9',
#   'user': 'rhuanbarros@gmail.com'},
#  {'created_at': datetime.datetime(2024, 8, 23, 17, 13, 55, 673000, tzinfo=<anvil.tz.tzoffset (-3.0 hour offset)>),
#   'question_data': <LiveObject: anvil.tables.Row>,
#   'question_txt': 'Logistic regression is a linear model used for regression tasks.',
#   'question_title': 'Machine Learning basics',
#   'question_type': 'true_or_false',
#   'question_level': 'beginner',
#   'got_it_right': True,
#   'session': '1d39bb99-5b10-cfba-8abf-1c12cf1e63a9',
#   'user': 'rhuanbarros@gmail.com'},
#  {'created_at': datetime.datetime(2024, 8, 23, 17, 14, 2, 518000, tzinfo=<anvil.tz.tzoffset (-3.0 hour offset)>),
#   'question_data': <LiveObject: anvil.tables.Row>,
#   'question_txt': 'Decision trees are used only for regression problems, not classification.',
#   'question_title': 'Machine Learning basics',
#   'question_type': 'true_or_false',
#   'question_level': 'beginner',
#   'got_it_right': True,
#   'session': '1d39bb99-5b10-cfba-8abf-1c12cf1e63a9',
#   'user': 'rhuanbarros@gmail.com'},
#  {'created_at': datetime.datetime(2024, 8, 23, 17, 14, 8, 624000, tzinfo=<anvil.tz.tzoffset (-3.0 hour offset)>),
#   'question_data': <LiveObject: anvil.tables.Row>,
#   'question_txt': 'K-means clustering guarantees convergence to the global optimum.',
#   'question_title': 'Machine Learning basics',
#   'question_type': 'true_or_false',
#   'question_level': 'beginner',
#   'got_it_right': True,
#   'session': '1d39bb99-5b10-cfba-8abf-1c12cf1e63a9',
#   'user': 'rhuanbarros@gmail.com'},
#  {'created_at': datetime.datetime(2024, 8, 23, 17, 14, 15, 847000, tzinfo=<anvil.tz.tzoffset (-3.0 hour offset)>),
#   'question_data': <LiveObject: anvil.tables.Row>,
#   'question_txt': 'In supervised learning, the model is trained on labeled data.',
#   'question_title': 'Machine Learning basics',
#   'question_type': 'true_or_false',
#   'question_level': 'beginner',
#   'got_it_right': True,
#   'session': '1d39bb99-5b10-cfba-8abf-1c12cf1e63a9',
#   'user': 'rhuanbarros@gmail.com'},
#  {'created_at': datetime.datetime(2024, 8, 23, 17, 14, 27, 765000, tzinfo=<anvil.tz.tzoffset (-3.0 hour offset)>),
#   'question_data': <LiveObject: anvil.tables.Row>,
#   'question_txt': 'Feature importance in a model indicates the order in which features were added during training.',
#   'question_title': 'Machine Learning basics',
#   'question_type': 'true_or_false',
#   'question_level': 'beginner',
#   'got_it_right': True,
#   'session': '1d39bb99-5b10-cfba-8abf-1c12cf1e63a9',
#   'user': 'rhuanbarros@gmail.com'},
#  {'created_at': datetime.datetime(2024, 8, 23, 17, 14, 35, 132000, tzinfo=<anvil.tz.tzoffset (-3.0 hour offset)>),
#   'question_data': <LiveObject: anvil.tables.Row>,
#   'question_txt': 'Overfitting occurs when a model performs well on unseen data.',
#   'question_title': 'Machine Learning basics',
#   'question_type': 'true_or_false',
#   'question_level': 'beginner',
#   'got_it_right': True,
#   'session': '1d39bb99-5b10-cfba-8abf-1c12cf1e63a9',
#   'user': 'rhuanbarros@gmail.com'},
#  {'created_at': datetime.datetime(2024, 8, 23, 17, 14, 39, 684000, tzinfo=<anvil.tz.tzoffset (-3.0 hour offset)>),
#   'question_data': <LiveObject: anvil.tables.Row>,
#   'question_txt': 'Neural networks are inspired by the functioning of the human brain.',
#   'question_title': 'Machine Learning basics',
#   'question_type': 'true_or_false',
#   'question_level': 'beginner',
#   'got_it_right': True,
#   'session': '1d39bb99-5b10-cfba-8abf-1c12cf1e63a9',
#   'user': 'rhuanbarros@gmail.com'},
#  {'created_at': datetime.datetime(2024, 8, 23, 17, 30, 51, 938000, tzinfo=<anvil.tz.tzoffset (-3.0 hour offset)>),
#   'question_data': <LiveObject: anvil.tables.Row>,
#   'question_txt': 'Recall measures the ability of a model to identify all relevant instances in a dataset.',
#   'question_title': 'Model performance',
#   'question_type': 'true_or_false',
#   'question_level': 'easy',
#   'got_it_right': True,
#   'session': '8001fde4-cea8-694b-45ce-79cef3fa51c1',
#   'user': 'rhuanbarros@gmail.com'},
#  {'created_at': datetime.datetime(2024, 8, 23, 17, 30, 58, 483000, tzinfo=<anvil.tz.tzoffset (-3.0 hour offset)>),
#   'question_data': <LiveObject: anvil.tables.Row>,
#   'question_txt': 'Precision is the ratio of true positives to the sum of true positives and true negatives.',
#   'question_title': 'Model performance',
#   'question_type': 'true_or_false',
#   'question_level': 'easy',
#   'got_it_right': False,
#   'session': '8001fde4-cea8-694b-45ce-79cef3fa51c1',
#   'user': 'rhuanbarros@gmail.com'},
#  {'created_at': datetime.datetime(2024, 8, 23, 17, 32, 9, 721000, tzinfo=<anvil.tz.tzoffset (-3.0 hour offset)>),
#   'question_data': <LiveObject: anvil.tables.Row>,
#   'question_txt': "A forged image perturbation of an unauthorized person's face would not make this person be authorized in face identification systems.",
#   'question_title': 'CS230 • Vulnerabilities of Neural Networks',
#   'question_type': 'true_or_false',
#   'question_level': 'hard',
#   'got_it_right': False,
#   'session': 'b24552eb-4253-f78e-eabf-01589741b628',
#   'user': 'rhuanbarros@gmail.com'},
#  {'created_at': datetime.datetime(2024, 8, 23, 17, 32, 56, 18000, tzinfo=<anvil.tz.tzoffset (-3.0 hour offset)>),
#   'question_data': <LiveObject: anvil.tables.Row>,
#   'question_txt': 'Accuracy is a suitable evaluation metric for imbalanced classification problems.',
#   'question_title': 'CS230 • Vulnerabilities of Neural Networks',
#   'question_type': 'true_or_false',
#   'question_level': 'intermediate',
#   'got_it_right': True,
#   'session': 'b24552eb-4253-f78e-eabf-01589741b628',
#   'user': 'rhuanbarros@gmail.com'},
#  {'created_at': datetime.datetime(2024, 8, 24, 18, 6, 40, 752000, tzinfo=<anvil.tz.tzoffset (-3.0 hour offset)>),
#   'question_data': <LiveObject: anvil.tables.Row>,
#   'question_txt': 'Using a deeper CNN always results in better performance on all image classification tasks.',
#   'question_title': 'CS231n • Loss Functions',
#   'question_type': 'true_or_false',
#   'question_level': 'hard',
#   'got_it_right': True,
#   'session': '855cad2f-d586-c5e3-b296-3dd384c3f82d',
#   'user': ''},
#  {'created_at': datetime.datetime(2024, 8, 24, 18, 12, 57, 966000, tzinfo=<anvil.tz.tzoffset (-3.0 hour offset)>),
#   'question_data': <LiveObject: anvil.tables.Row>,
#   'question_txt': 'Entropy and cross-entropy are used interchangeably in language models.$$mathrm{H}(P) = mathcal{E}(P, Q),$$',
#   'question_title': 'Test',
#   'question_type': 'true_or_false',
#   'question_level': 'easy',
#   'got_it_right': True,
#   'session': 'd62a311b-3f92-b853-5faf-eb940b997e51',
#   'user': ''},
#  {'created_at': datetime.datetime(2024, 8, 24, 18, 57, 47, 134000, tzinfo=<anvil.tz.tzoffset (-3.0 hour offset)>),
#   'question_data': <LiveObject: anvil.tables.Row>,
#   'question_txt': 'Entropy and cross-entropy are used interchangeably in language models.$$mathrm{H}(P) = mathcal{E}(P, Q),$$',
#   'question_title': 'Test',
#   'question_type': 'true_or_false',
#   'question_level': 'easy',
#   'got_it_right': True,
#   'session': '6dcc5c5e-0c05-86e8-c4f3-e8d7e6d6e308',
#   'user': 'teste@teste.com'},
#  {'created_at': datetime.datetime(2024, 8, 25, 8, 53, 6, 792000, tzinfo=<anvil.tz.tzoffset (-3.0 hour offset)>),
#   'question_data': <LiveObject: anvil.tables.Row>,
#   'question_txt': 'A matrix and its transpose have the same determinant.',
#   'question_title': 'Linear Algebra',
#   'question_type': 'true_or_false',
#   'question_level': 'beginner',
#   'got_it_right': False,
#   'session': 'fe5f9699-b07a-e67f-8032-b99196d949ff',
#   'user': 'teste@teste.com'},
#  {'created_at': datetime.datetime(2024, 8, 25, 8, 53, 15, 884000, tzinfo=<anvil.tz.tzoffset (-3.0 hour offset)>),
#   'question_data': <LiveObject: anvil.tables.Row>,
#   'question_txt': 'Basis vectors are not essential for defining a vector space.',
#   'question_title': 'Linear Algebra',
#   'question_type': 'true_or_false',
#   'question_level': 'beginner',
#   'got_it_right': True,
#   'session': 'fe5f9699-b07a-e67f-8032-b99196d949ff',
#   'user': 'teste@teste.com'},
#  {'created_at': datetime.datetime(2024, 8, 25, 8, 53, 33, 978000, tzinfo=<anvil.tz.tzoffset (-3.0 hour offset)>),
#   'question_data': <LiveObject: anvil.tables.Row>,
#   'question_txt': 'If a vector \\(\\mathbf{v}\\) can be expressed as a linear combination of vectors \\(\\mathbf{a}\\) and \\(\\mathbf{b}\\), then \\(\\mathbf{a}\\) and \\(\\mathbf{b}\\) must be scalar multiples of each other.',
#   'question_title': 'Linear Algebra',
#   'question_type': 'true_or_false',
#   'question_level': 'intermediate',
#   'got_it_right': False,
#   'session': 'fe5f9699-b07a-e67f-8032-b99196d949ff',
#   'user': 'teste@teste.com'},
#  {'created_at': datetime.datetime(2024, 8, 25, 8, 55, 14, 524000, tzinfo=<anvil.tz.tzoffset (-3.0 hour offset)>),
#   'question_data': <LiveObject: anvil.tables.Row>,
#   'question_txt': 'The zero vector cannot be part of a basis for a non-trivial vector space.',
#   'question_title': 'Linear Algebra',
#   'question_type': 'true_or_false',
#   'question_level': 'hard',
#   'got_it_right': False,
#   'session': 'fe5f9699-b07a-e67f-8032-b99196d949ff',
#   'user': 'teste@teste.com'},
#  {'created_at': datetime.datetime(2024, 8, 25, 9, 17, 18, 303000, tzinfo=<anvil.tz.tzoffset (-3.0 hour offset)>),
#   'question_data': <LiveObject: anvil.tables.Row>,
#   'question_txt': 'The non-commutative property of matrix multiplication is a rare occurrence.',
#   'question_title': 'Linear Algebra',
#   'question_type': 'true_or_false',
#   'question_level': 'intermediate',
#   'got_it_right': True,
#   'session': '06b5f207-45f5-12ac-da64-e80342a6001d',
#   'user': 'teste@teste.com'},
#  {'created_at': datetime.datetime(2024, 8, 25, 9, 17, 28, 56000, tzinfo=<anvil.tz.tzoffset (-3.0 hour offset)>),
#   'question_data': <LiveObject: anvil.tables.Row>,
#   'question_txt': 'The determinant of the identity matrix is always 1.',
#   'question_title': 'Linear Algebra',
#   'question_type': 'true_or_false',
#   'question_level': 'intermediate',
#   'got_it_right': True,
#   'session': '06b5f207-45f5-12ac-da64-e80342a6001d',
#   'user': 'teste@teste.com'},
#  {'created_at': datetime.datetime(2024, 8, 25, 10, 10, 28, 28000, tzinfo=<anvil.tz.tzoffset (-3.0 hour offset)>),
#   'question_data': <LiveObject: anvil.tables.Row>,
#   'question_txt': 'The determinant of the identity matrix is always 1.',
#   'question_title': 'Linear Algebra',
#   'question_type': 'true_or_false',
#   'question_level': 'intermediate',
#   'got_it_right': True,
#   'session': '2f8d108e-f863-36fe-1c72-9b7f3e387ce4',
#   'user': 'teste@teste.com'},
#  {'created_at': datetime.datetime(2024, 8, 25, 10, 10, 51, 312000, tzinfo=<anvil.tz.tzoffset (-3.0 hour offset)>),
#   'question_data': <LiveObject: anvil.tables.Row>,
#   'question_txt': 'The non-commutative property of matrix multiplication is a rare occurrence.',
#   'question_title': 'Linear Algebra',
#   'question_type': 'true_or_false',
#   'question_level': 'intermediate',
#   'got_it_right': True,
#   'session': '2f8d108e-f863-36fe-1c72-9b7f3e387ce4',
#   'user': 'teste@teste.com'},
#  {'created_at': datetime.datetime(2024, 8, 25, 10, 11, 5, 469000, tzinfo=<anvil.tz.tzoffset (-3.0 hour offset)>),
#   'question_data': <LiveObject: anvil.tables.Row>,
#   'question_txt': 'Basis vectors are not essential for defining a vector space.',
#   'question_title': 'Linear Algebra',
#   'question_type': 'true_or_false',
#   'question_level': 'beginner',
#   'got_it_right': True,
#   'session': '2f8d108e-f863-36fe-1c72-9b7f3e387ce4',
#   'user': 'teste@teste.com'},
#  {'created_at': datetime.datetime(2024, 8, 25, 10, 11, 27, 891000, tzinfo=<anvil.tz.tzoffset (-3.0 hour offset)>),
#   'question_data': <LiveObject: anvil.tables.Row>,
#   'question_txt': 'Entropy and cross-entropy are used interchangeably in language models.$$mathrm{H}(P) = mathcal{E}(P, Q),$$',
#   'question_title': 'Test',
#   'question_type': 'true_or_false',
#   'question_level': 'easy',
#   'got_it_right': True,
#   'session': '2f8d108e-f863-36fe-1c72-9b7f3e387ce4',
#   'user': 'teste@teste.com'},
#  {'created_at': datetime.datetime(2024, 8, 25, 10, 11, 44, 221000, tzinfo=<anvil.tz.tzoffset (-3.0 hour offset)>),
#   'question_data': <LiveObject: anvil.tables.Row>,
#   'question_txt': 'Using a deeper CNN always results in better performance on all image classification tasks.',
#   'question_title': 'CS231n • Loss Functions',
#   'question_type': 'true_or_false',
#   'question_level': 'hard',
#   'got_it_right': True,
#   'session': '2f8d108e-f863-36fe-1c72-9b7f3e387ce4',
#   'user': 'teste@teste.com'},
#  {'created_at': datetime.datetime(2024, 8, 25, 10, 12, 14, 410000, tzinfo=<anvil.tz.tzoffset (-3.0 hour offset)>),
#   'question_data': <LiveObject: anvil.tables.Row>,
#   'question_txt': 'Accuracy is a suitable evaluation metric for imbalanced classification problems.',
#   'question_title': 'CS230 • Vulnerabilities of Neural Networks',
#   'question_type': 'true_or_false',
#   'question_level': 'intermediate',
#   'got_it_right': True,
#   'session': '2f8d108e-f863-36fe-1c72-9b7f3e387ce4',
#   'user': 'teste@teste.com'}]

# %%
len(answers_list)
# Out:
# 74

# %%
aq = {}
total_wrong = 0
total_right = 0

for ans in answers_list:
    key = ans["question_txt"]
    got_it_right = ans["got_it_right"]

    if key not in aq:
        aq[key] = {
            "question_data": ans["question_data"],
            "last_answered": ans["created_at"],
            "wrong": 0,
            "right": 1,
        }
    
    aq[key]["last_answered"] = max(ans["created_at"], aq[key]["last_answered"])

    if got_it_right:
        aq[key]["right"] += 1
        total_wrong += 1
    else:
        aq[key]["wrong"] += 1
        total_right += 1

# %%
now_aware = datetime.now(pytz.UTC)
total_time = 0
for key in aq:
    aq[key]["wrong_normalized"] = aq[key]["wrong"] / total_wrong
    aq[key]["right_normalized"] = aq[key]["right"] / total_right
    aq[key]["time_diff"] = int( (now_aware - aq[key]["last_answered"]).total_seconds() )
    total_time += aq[key]["time_diff"]

# %%
for key in aq:
    aq[key]["time_diff"] = aq[key]["time_diff"] / total_time

# %%
def score(row):
    weights = {"wrong_normalized": 1, "time_diff": 1}

    return (
        row["wrong_normalized"] * weights["wrong_normalized"]
        + row["time_diff"] * weights["time_diff"]
    )

# %%
for key in aq:
    aq[key]["score"] = score(aq[key])

# %%
aq_list = [(v["question_data"], v["score"], k) for k, v in aq.items()]
aq_list
# Out:
# [(<LiveObject: anvil.tables.Row>,
#   0.11118388538344105,
#   'Entropy is a measure of the average uncertainty in a set of outcomes, while cross-entropy measures the difference between two probability distributions.'),
#  (<LiveObject: anvil.tables.Row>,
#   0.07943757018892975,
#   'Cross-entropy loss measures the difference between predicted probabilities and actual outcomes, while entropy quantifies the uncertainty in a probability distribution.'),
#  (<LiveObject: anvil.tables.Row>,
#   0.07944144398481699,
#   'Entropy is a measure of uncertainty in a probability distribution, while cross-entropy measures the difference between two probability distributions.'),
#  (<LiveObject: anvil.tables.Row>,
#   0.07944116053633743,
#   'Cross-entropy loss is the same as perplexity, used to evaluate language models.'),
#  (<LiveObject: anvil.tables.Row>,
#   0.0793533859905022,
#   'A linear transformation preserves linear combinations of vectors, but not their magnitudes.'),
#  (<LiveObject: anvil.tables.Row>,
#   0.09522403979285513,
#   'Cross-Entropy is always less than or equal to Entropy for a given probability distribution.'),
#  (<LiveObject: anvil.tables.Row>,
#   0.0305816343903883,
#   "Perplexity is used as a loss function in machine learning models to optimize the model's performance."),
#  (<LiveObject: anvil.tables.Row>,
#   0.03047420741663733,
#   'Minimizing cross-entropy loss during training improves the performance of a language model.'),
#  (<LiveObject: anvil.tables.Row>,
#   0.013872252037852844,
#   'Recall measures the ability of a model to identify all relevant instances in a dataset.'),
#  (<LiveObject: anvil.tables.Row>,
#   0.04561771688692548,
#   'Precision is the ratio of true positives to the sum of true positives and true negatives.'),
#  (<LiveObject: anvil.tables.Row>,
#   0.01396418382805486,
#   'Neural networks are inspired by the functioning of the human brain.'),
#  (<LiveObject: anvil.tables.Row>,
#   0.013973159696574072,
#   'Accuracy is the best metric for imbalanced datasets.'),
#  (<LiveObject: anvil.tables.Row>,
#   0.013983458324664534,
#   'Increasing model complexity typically reduces bias and increases variance.'),
#  (<LiveObject: anvil.tables.Row>,
#   0.013975994181369612,
#   'Logistic Regression is used for regression tasks, not classification.'),
#  (<LiveObject: anvil.tables.Row>,
#   0.013970136246125496,
#   'Cross-validation is a technique used to train a model on multiple subsets of the data and then average the results.'),
#  (<LiveObject: anvil.tables.Row>,
#   0.013981568668134174,
#   'Classification is a type of unsupervised learning technique.'),
#  (<LiveObject: anvil.tables.Row>,
#   0.02985061626243629,
#   'PCA is a supervised learning technique.'),
#  (<LiveObject: anvil.tables.Row>,
#   0.013981190736828101,
#   'Logistic regression is used for continuous target variables.'),
#  (<LiveObject: anvil.tables.Row>,
#   0.013972687282441481,
#   'Feature scaling is not necessary in machine learning.'),
#  (<LiveObject: anvil.tables.Row>,
#   0.013978167286379526,
#   'Cross-validation is a technique used to prevent underfitting in machine learning models.'),
#  (<LiveObject: anvil.tables.Row>,
#   0.013976372112675684,
#   'Feature scaling is not necessary for tree-based models.'),
#  (<LiveObject: anvil.tables.Row>,
#   0.013982041082266763,
#   'Increasing model complexity often leads to lower bias and higher variance.'),
#  (<LiveObject: anvil.tables.Row>,
#   0.013974954870277913,
#   'Feature engineering is the process of selecting the most complex features for a model.'),
#  (<LiveObject: anvil.tables.Row>,
#   0.013982891427705426,
#   'Precision and recall are two common evaluation metrics for classification models.'),
#  (<LiveObject: anvil.tables.Row>,
#   0.013980623839868993,
#   'Having high bias in a model can lead to overfitting.'),
#  (<LiveObject: anvil.tables.Row>,
#   0.02985250591896665,
#   'Regularization is a technique used to encourage complex models in machine learning.'),
#  (<LiveObject: anvil.tables.Row>,
#   0.01397703349246131,
#   'Overfitting occurs when a model performs well on the training data but poorly on new, unseen data.'),
#  (<LiveObject: anvil.tables.Row>,
#   0.013975427284410504,
#   'Random Forest is an example of a single learning algorithm, not an ensemble method.'),
#  (<LiveObject: anvil.tables.Row>,
#   0.013974482456145325,
#   'Overfitting occurs when a model performs well on the training data but poorly on unseen data.'),
#  (<LiveObject: anvil.tables.Row>,
#   0.013973915559186216,
#   'Decision trees are used only for regression tasks and not for classification.'),
#  (<LiveObject: anvil.tables.Row>,
#   0.013973537627880143,
#   'Decision trees are used only for regression problems.'),
#  (<LiveObject: anvil.tables.Row>,
#   0.013971742454176301,
#   'Neural networks with more hidden layers are always better than shallow networks.'),
#  (<LiveObject: anvil.tables.Row>,
#   0.013971175557217193,
#   'K-Nearest Neighbors (KNN) is a supervised learning algorithm.'),
#  (<LiveObject: anvil.tables.Row>,
#   0.013969285900686834,
#   'Bagging and Boosting are types of unsupervised learning techniques.'),
#  (<LiveObject: anvil.tables.Row>,
#   0.013968341072421654,
#   'Logistic regression is a linear model used for regression tasks.'),
#  (<LiveObject: anvil.tables.Row>,
#   0.013967679692636027,
#   'Decision trees are used only for regression problems, not classification.'),
#  (<LiveObject: anvil.tables.Row>,
#   0.013967112795676919,
#   'K-means clustering guarantees convergence to the global optimum.'),
#  (<LiveObject: anvil.tables.Row>,
#   0.013966356933064776,
#   'In supervised learning, the model is trained on labeled data.'),
#  (<LiveObject: anvil.tables.Row>,
#   0.01396522313914656,
#   'Feature importance in a model indicates the order in which features were added during training.'),
#  (<LiveObject: anvil.tables.Row>,
#   0.013964561759360934,
#   'Overfitting occurs when a model performs well on unseen data.'),
#  (<LiveObject: anvil.tables.Row>,
#   0.02973789825040031,
#   "A forged image perturbation of an unauthorized person's face would not make this person be authorized in face identification systems."),
#  (<LiveObject: anvil.tables.Row>,
#   3.221864384263923e-05,
#   'Accuracy is a suitable evaluation metric for imbalanced classification problems.'),
#  (<LiveObject: anvil.tables.Row>,
#   3.505312863817934e-05,
#   'Using a deeper CNN always results in better performance on all image classification tasks.'),
#  (<LiveObject: anvil.tables.Row>,
#   3.6564853862467396e-05,
#   'Entropy and cross-entropy are used interchangeably in language models.$$mathrm{H}(P) = mathcal{E}(P, Q),$$'),
#  (<LiveObject: anvil.tables.Row>,
#   0.016353744494339476,
#   'A matrix and its transpose have the same determinant.'),
#  (<LiveObject: anvil.tables.Row>,
#   3.873795887238148e-05,
#   'Basis vectors are not essential for defining a vector space.'),
#  (<LiveObject: anvil.tables.Row>,
#   0.016351193458023487,
#   'If a vector \\(\\mathbf{v}\\) can be expressed as a linear combination of vectors \\(\\mathbf{a}\\) and \\(\\mathbf{b}\\), then \\(\\mathbf{a}\\) and \\(\\mathbf{b}\\) must be scalar multiples of each other.'),
#  (<LiveObject: anvil.tables.Row>,
#   0.016341745175371687,
#   'The zero vector cannot be part of a basis for a non-trivial vector space.'),
#  (<LiveObject: anvil.tables.Row>,
#   4.006071844363353e-05,
#   'The non-commutative property of matrix multiplication is a rare occurrence.'),
#  (<LiveObject: anvil.tables.Row>,
#   4.223382345354761e-05,
#   'The determinant of the identity matrix is always 1.')]

# %%
questions_ranking = sorted( aq_list, key=lambda row: row[1], reverse=True )
questions_ranking
# Out:
# [(<LiveObject: anvil.tables.Row>,
#   0.11118388538344105,
#   'Entropy is a measure of the average uncertainty in a set of outcomes, while cross-entropy measures the difference between two probability distributions.'),
#  (<LiveObject: anvil.tables.Row>,
#   0.09522403979285513,
#   'Cross-Entropy is always less than or equal to Entropy for a given probability distribution.'),
#  (<LiveObject: anvil.tables.Row>,
#   0.07944144398481699,
#   'Entropy is a measure of uncertainty in a probability distribution, while cross-entropy measures the difference between two probability distributions.'),
#  (<LiveObject: anvil.tables.Row>,
#   0.07944116053633743,
#   'Cross-entropy loss is the same as perplexity, used to evaluate language models.'),
#  (<LiveObject: anvil.tables.Row>,
#   0.07943757018892975,
#   'Cross-entropy loss measures the difference between predicted probabilities and actual outcomes, while entropy quantifies the uncertainty in a probability distribution.'),
#  (<LiveObject: anvil.tables.Row>,
#   0.0793533859905022,
#   'A linear transformation preserves linear combinations of vectors, but not their magnitudes.'),
#  (<LiveObject: anvil.tables.Row>,
#   0.04561771688692548,
#   'Precision is the ratio of true positives to the sum of true positives and true negatives.'),
#  (<LiveObject: anvil.tables.Row>,
#   0.0305816343903883,
#   "Perplexity is used as a loss function in machine learning models to optimize the model's performance."),
#  (<LiveObject: anvil.tables.Row>,
#   0.03047420741663733,
#   'Minimizing cross-entropy loss during training improves the performance of a language model.'),
#  (<LiveObject: anvil.tables.Row>,
#   0.02985250591896665,
#   'Regularization is a technique used to encourage complex models in machine learning.'),
#  (<LiveObject: anvil.tables.Row>,
#   0.02985061626243629,
#   'PCA is a supervised learning technique.'),
#  (<LiveObject: anvil.tables.Row>,
#   0.02973789825040031,
#   "A forged image perturbation of an unauthorized person's face would not make this person be authorized in face identification systems."),
#  (<LiveObject: anvil.tables.Row>,
#   0.016353744494339476,
#   'A matrix and its transpose have the same determinant.'),
#  (<LiveObject: anvil.tables.Row>,
#   0.016351193458023487,
#   'If a vector \\(\\mathbf{v}\\) can be expressed as a linear combination of vectors \\(\\mathbf{a}\\) and \\(\\mathbf{b}\\), then \\(\\mathbf{a}\\) and \\(\\mathbf{b}\\) must be scalar multiples of each other.'),
#  (<LiveObject: anvil.tables.Row>,
#   0.016341745175371687,
#   'The zero vector cannot be part of a basis for a non-trivial vector space.'),
#  (<LiveObject: anvil.tables.Row>,
#   0.013983458324664534,
#   'Increasing model complexity typically reduces bias and increases variance.'),
#  (<LiveObject: anvil.tables.Row>,
#   0.013982891427705426,
#   'Precision and recall are two common evaluation metrics for classification models.'),
#  (<LiveObject: anvil.tables.Row>,
#   0.013982041082266763,
#   'Increasing model complexity often leads to lower bias and higher variance.'),
#  (<LiveObject: anvil.tables.Row>,
#   0.013981568668134174,
#   'Classification is a type of unsupervised learning technique.'),
#  (<LiveObject: anvil.tables.Row>,
#   0.013981190736828101,
#   'Logistic regression is used for continuous target variables.'),
#  (<LiveObject: anvil.tables.Row>,
#   0.013980623839868993,
#   'Having high bias in a model can lead to overfitting.'),
#  (<LiveObject: anvil.tables.Row>,
#   0.013978167286379526,
#   'Cross-validation is a technique used to prevent underfitting in machine learning models.'),
#  (<LiveObject: anvil.tables.Row>,
#   0.01397703349246131,
#   'Overfitting occurs when a model performs well on the training data but poorly on new, unseen data.'),
#  (<LiveObject: anvil.tables.Row>,
#   0.013976372112675684,
#   'Feature scaling is not necessary for tree-based models.'),
#  (<LiveObject: anvil.tables.Row>,
#   0.013975994181369612,
#   'Logistic Regression is used for regression tasks, not classification.'),
#  (<LiveObject: anvil.tables.Row>,
#   0.013975427284410504,
#   'Random Forest is an example of a single learning algorithm, not an ensemble method.'),
#  (<LiveObject: anvil.tables.Row>,
#   0.013974954870277913,
#   'Feature engineering is the process of selecting the most complex features for a model.'),
#  (<LiveObject: anvil.tables.Row>,
#   0.013974482456145325,
#   'Overfitting occurs when a model performs well on the training data but poorly on unseen data.'),
#  (<LiveObject: anvil.tables.Row>,
#   0.013973915559186216,
#   'Decision trees are used only for regression tasks and not for classification.'),
#  (<LiveObject: anvil.tables.Row>,
#   0.013973537627880143,
#   'Decision trees are used only for regression problems.'),
#  (<LiveObject: anvil.tables.Row>,
#   0.013973159696574072,
#   'Accuracy is the best metric for imbalanced datasets.'),
#  (<LiveObject: anvil.tables.Row>,
#   0.013972687282441481,
#   'Feature scaling is not necessary in machine learning.'),
#  (<LiveObject: anvil.tables.Row>,
#   0.013971742454176301,
#   'Neural networks with more hidden layers are always better than shallow networks.'),
#  (<LiveObject: anvil.tables.Row>,
#   0.013971175557217193,
#   'K-Nearest Neighbors (KNN) is a supervised learning algorithm.'),
#  (<LiveObject: anvil.tables.Row>,
#   0.013970136246125496,
#   'Cross-validation is a technique used to train a model on multiple subsets of the data and then average the results.'),
#  (<LiveObject: anvil.tables.Row>,
#   0.013969285900686834,
#   'Bagging and Boosting are types of unsupervised learning techniques.'),
#  (<LiveObject: anvil.tables.Row>,
#   0.013968341072421654,
#   'Logistic regression is a linear model used for regression tasks.'),
#  (<LiveObject: anvil.tables.Row>,
#   0.013967679692636027,
#   'Decision trees are used only for regression problems, not classification.'),
#  (<LiveObject: anvil.tables.Row>,
#   0.013967112795676919,
#   'K-means clustering guarantees convergence to the global optimum.'),
#  (<LiveObject: anvil.tables.Row>,
#   0.013966356933064776,
#   'In supervised learning, the model is trained on labeled data.'),
#  (<LiveObject: anvil.tables.Row>,
#   0.01396522313914656,
#   'Feature importance in a model indicates the order in which features were added during training.'),
#  (<LiveObject: anvil.tables.Row>,
#   0.013964561759360934,
#   'Overfitting occurs when a model performs well on unseen data.'),
#  (<LiveObject: anvil.tables.Row>,
#   0.01396418382805486,
#   'Neural networks are inspired by the functioning of the human brain.'),
#  (<LiveObject: anvil.tables.Row>,
#   0.013872252037852844,
#   'Recall measures the ability of a model to identify all relevant instances in a dataset.'),
#  (<LiveObject: anvil.tables.Row>,
#   4.223382345354761e-05,
#   'The determinant of the identity matrix is always 1.'),
#  (<LiveObject: anvil.tables.Row>,
#   4.006071844363353e-05,
#   'The non-commutative property of matrix multiplication is a rare occurrence.'),
#  (<LiveObject: anvil.tables.Row>,
#   3.873795887238148e-05,
#   'Basis vectors are not essential for defining a vector space.'),
#  (<LiveObject: anvil.tables.Row>,
#   3.6564853862467396e-05,
#   'Entropy and cross-entropy are used interchangeably in language models.$$mathrm{H}(P) = mathcal{E}(P, Q),$$'),
#  (<LiveObject: anvil.tables.Row>,
#   3.505312863817934e-05,
#   'Using a deeper CNN always results in better performance on all image classification tasks.'),
#  (<LiveObject: anvil.tables.Row>,
#   3.221864384263923e-05,
#   'Accuracy is a suitable evaluation metric for imbalanced classification problems.')]

# %%
questions_ranking_ = [ q[0] for q in questions_ranking]
questions_ranking_
# Out:
# [<LiveObject: anvil.tables.Row>,
#  <LiveObject: anvil.tables.Row>,
#  <LiveObject: anvil.tables.Row>,
#  <LiveObject: anvil.tables.Row>,
#  <LiveObject: anvil.tables.Row>,
#  <LiveObject: anvil.tables.Row>,
#  <LiveObject: anvil.tables.Row>,
#  <LiveObject: anvil.tables.Row>,
#  <LiveObject: anvil.tables.Row>,
#  <LiveObject: anvil.tables.Row>,
#  <LiveObject: anvil.tables.Row>,
#  <LiveObject: anvil.tables.Row>,
#  <LiveObject: anvil.tables.Row>,
#  <LiveObject: anvil.tables.Row>,
#  <LiveObject: anvil.tables.Row>,
#  <LiveObject: anvil.tables.Row>,
#  <LiveObject: anvil.tables.Row>,
#  <LiveObject: anvil.tables.Row>,
#  <LiveObject: anvil.tables.Row>,
#  <LiveObject: anvil.tables.Row>,
#  <LiveObject: anvil.tables.Row>,
#  <LiveObject: anvil.tables.Row>,
#  <LiveObject: anvil.tables.Row>,
#  <LiveObject: anvil.tables.Row>,
#  <LiveObject: anvil.tables.Row>,
#  <LiveObject: anvil.tables.Row>,
#  <LiveObject: anvil.tables.Row>,
#  <LiveObject: anvil.tables.Row>,
#  <LiveObject: anvil.tables.Row>,
#  <LiveObject: anvil.tables.Row>,
#  <LiveObject: anvil.tables.Row>,
#  <LiveObject: anvil.tables.Row>,
#  <LiveObject: anvil.tables.Row>,
#  <LiveObject: anvil.tables.Row>,
#  <LiveObject: anvil.tables.Row>,
#  <LiveObject: anvil.tables.Row>,
#  <LiveObject: anvil.tables.Row>,
#  <LiveObject: anvil.tables.Row>,
#  <LiveObject: anvil.tables.Row>,
#  <LiveObject: anvil.tables.Row>,
#  <LiveObject: anvil.tables.Row>,
#  <LiveObject: anvil.tables.Row>,
#  <LiveObject: anvil.tables.Row>,
#  <LiveObject: anvil.tables.Row>,
#  <LiveObject: anvil.tables.Row>,
#  <LiveObject: anvil.tables.Row>,
#  <LiveObject: anvil.tables.Row>,
#  <LiveObject: anvil.tables.Row>,
#  <LiveObject: anvil.tables.Row>,
#  <LiveObject: anvil.tables.Row>]

# %%
aq_list_2 = [(v["score"], v["wrong_normalized"], v["time_diff"] , k) for k, v in aq.items()]
questions_ranking_2 = sorted( aq_list_2, key=lambda row: row[1], reverse=True )

df = pd.DataFrame(questions_ranking_2)
df.columns = [ "score", "wrong_normalized", "time_diff", "question_txt"]
df.head()
# Out:
#       score  wrong_normalized  time_diff  \
# 0  0.111184          0.031746   0.079438
# 1  0.045618          0.031746   0.013872
# 2  0.095224          0.015873   0.079351
# 3  0.029851          0.015873   0.013978
# 4  0.029853          0.015873   0.013979
#
#                                         question_txt
# 0  Entropy is a measure of the average uncertaint...
# 1  Precision is the ratio of true positives to th...
# 2  Cross-Entropy is always less than or equal to ...
# 3            PCA is a supervised learning technique.
# 4  Regularization is a technique used to encourag...

# %%
df
# Out:
#        score  wrong_normalized  time_diff  \
# 0   0.111184          0.031746   0.079438
# 1   0.045618          0.031746   0.013872
# 2   0.095224          0.015873   0.079351
# 3   0.029851          0.015873   0.013978
# 4   0.029853          0.015873   0.013979
# 5   0.029738          0.015873   0.013865
# 6   0.016354          0.015873   0.000481
# 7   0.016351          0.015873   0.000478
# 8   0.016342          0.015873   0.000469
# 9   0.079438          0.000000   0.079438
# 10  0.079441          0.000000   0.079441
# 11  0.079441          0.000000   0.079441
# 12  0.079353          0.000000   0.079353
# 13  0.030582          0.000000   0.030582
# 14  0.030474          0.000000   0.030474
# 15  0.013872          0.000000   0.013872
# 16  0.013964          0.000000   0.013964
# 17  0.013973          0.000000   0.013973
# 18  0.013983          0.000000   0.013983
# 19  0.013976          0.000000   0.013976
# 20  0.013970          0.000000   0.013970
# 21  0.013982          0.000000   0.013982
# 22  0.013981          0.000000   0.013981
# 23  0.013973          0.000000   0.013973
# 24  0.013978          0.000000   0.013978
# 25  0.013976          0.000000   0.013976
# 26  0.013982          0.000000   0.013982
# 27  0.013975          0.000000   0.013975
# 28  0.013983          0.000000   0.013983
# 29  0.013981          0.000000   0.013981
# 30  0.013977          0.000000   0.013977
# 31  0.013975          0.000000   0.013975
# 32  0.013974          0.000000   0.013974
# 33  0.013974          0.000000   0.013974
# 34  0.013974          0.000000   0.013974
# 35  0.013972          0.000000   0.013972
# 36  0.013971          0.000000   0.013971
# 37  0.013969          0.000000   0.013969
# 38  0.013968          0.000000   0.013968
# 39  0.013968          0.000000   0.013968
# 40  0.013967          0.000000   0.013967
# 41  0.013966          0.000000   0.013966
# 42  0.013965          0.000000   0.013965
# 43  0.013965          0.000000   0.013965
# 44  0.000032          0.000000   0.000032
# 45  0.000035          0.000000   0.000035
# 46  0.000037          0.000000   0.000037
# 47  0.000039          0.000000   0.000039
# 48  0.000040          0.000000   0.000040
# 49  0.000042          0.000000   0.000042
#
#                                          question_txt
# 0   Entropy is a measure of the average uncertaint...
# 1   Precision is the ratio of true positives to th...
# 2   Cross-Entropy is always less than or equal to ...
# 3             PCA is a supervised learning technique.
# 4   Regularization is a technique used to encourag...
# 5   A forged image perturbation of an unauthorized...
# 6   A matrix and its transpose have the same deter...
# 7   If a vector \(\mathbf{v}\) can be expressed as...
# 8   The zero vector cannot be part of a basis for ...
# 9   Cross-entropy loss measures the difference bet...
# 10  Entropy is a measure of uncertainty in a proba...
# 11  Cross-entropy loss is the same as perplexity, ...
# 12  A linear transformation preserves linear combi...
# 13  Perplexity is used as a loss function in machi...
# 14  Minimizing cross-entropy loss during training ...
# 15  Recall measures the ability of a model to iden...
# 16  Neural networks are inspired by the functionin...
# 17  Accuracy is the best metric for imbalanced dat...
# 18  Increasing model complexity typically reduces ...
# 19  Logistic Regression is used for regression tas...
# 20  Cross-validation is a technique used to train ...
# 21  Classification is a type of unsupervised learn...
# 22  Logistic regression is used for continuous tar...
# 23  Feature scaling is not necessary in machine le...
# 24  Cross-validation is a technique used to preven...
# 25  Feature scaling is not necessary for tree-base...
# 26  Increasing model complexity often leads to low...
# 27  Feature engineering is the process of selectin...
# 28  Precision and recall are two common evaluation...
# 29  Having high bias in a model can lead to overfi...
# 30  Overfitting occurs when a model performs well ...
# 31  Random Forest is an example of a single learni...
# 32  Overfitting occurs when a model performs well ...
# 33  Decision trees are used only for regression ta...
# 34  Decision trees are used only for regression pr...
# 35  Neural networks with more hidden layers are al...
# 36  K-Nearest Neighbors (KNN) is a supervised lear...
# 37  Bagging and Boosting are types of unsupervised...
# 38  Logistic regression is a linear model used for...
# 39  Decision trees are used only for regression pr...
# 40  K-means clustering guarantees convergence to t...
# 41  In supervised learning, the model is trained o...
# 42  Feature importance in a model indicates the or...
# 43  Overfitting occurs when a model performs well ...
# 44  Accuracy is a suitable evaluation metric for i...
# 45  Using a deeper CNN always results in better pe...
# 46  Entropy and cross-entropy are used interchange...
# 47  Basis vectors are not essential for defining a...
# 48  The non-commutative property of matrix multipl...
# 49  The determinant of the identity matrix is alwa...
